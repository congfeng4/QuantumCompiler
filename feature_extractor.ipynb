# %%
import transformers

# %%
from transformers import BertConfig, AutoModelForSequenceClassification

# 创建一个配置对象
config = BertConfig(
    hidden_size=768,
    num_attention_heads=12,
    num_hidden_layers=12,
    num_labels=2,  # 二分类
    vocab_size=30522,
    intermediate_size=3072,
    max_position_embeddings=512
)

# 使用 config 构造模型（无预训练权重）
model = AutoModelForSequenceClassification.from_config(config)

# %%
model()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:1481, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1473 r"""
#    1474 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1475     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1476     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1477     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1478 """
#    1479 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1481 outputs = self.bert(
#    1482     input_ids,
#    1483     attention_mask=attention_mask,
#    1484     token_type_ids=token_type_ids,
#    1485     position_ids=position_ids,
#    1486     head_mask=head_mask,
#    1487     inputs_embeds=inputs_embeds,
#    1488     output_attentions=output_attentions,
#    1489     output_hidden_states=output_hidden_states,
#    1490     return_dict=return_dict,
#    1491 )
#    1493 pooled_output = outputs[1]
#    1495 pooled_output = self.dropout(pooled_output)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/bert/modeling_bert.py:914, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     912     input_shape = inputs_embeds.size()[:-1]
#     913 else:
# --> 914     raise ValueError("You have to specify either input_ids or inputs_embeds")
#     916 batch_size, seq_length = input_shape
#     917 device = input_ids.device if input_ids is not None else inputs_embeds.device
#
# ValueError: You have to specify either input_ids or inputs_embeds
