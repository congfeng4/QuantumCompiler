# %%
import shelve

# %%
db = shelve.open('./output/db/nam_circs', writeback=True)

# %%
for k, v in list(db.items()):
    print(k, v)
    if v is None:
        del db[k]
# Out:
# barenco_tof_10.qasm-Star {'metric/depth_ratio': 1.2274336283185843, 'metric/ops_ratio': 1.0531111111111113, 'metric/cx_ratio': 1.7651041666666665}
# barenco_tof_3.qasm-Star {'metric/depth_ratio': 1.1733333333333331, 'metric/ops_ratio': 1.089655172413793, 'metric/cx_ratio': 1.725}
# csla_mux_3.qasm-Star {'metric/depth_ratio': 2.2444444444444445, 'metric/ops_ratio': 1.1688235294117646, 'metric/cx_ratio': 2.05375}
# csum_mux_9.qasm-Star {'metric/depth_ratio': 5.9171875, 'metric/ops_ratio': 1.1385714285714283, 'metric/cx_ratio': 2.0273809523809523}
# gf2^4_mult.qasm-Star {'metric/depth_ratio': 1.913392857142857, 'metric/ops_ratio': 1.1515555555555554, 'metric/cx_ratio': 2.164646464646465}
# gf2^5_mult.qasm-Star {'metric/depth_ratio': 2.332191780821918, 'metric/ops_ratio': 1.1752161383285302, 'metric/cx_ratio': 2.222077922077922}
# gf2^6_mult.qasm-Star {'metric/depth_ratio': 2.6157608695652175, 'metric/ops_ratio': 1.1997979797979799, 'metric/cx_ratio': 2.2981900452488686}
# ...

# %%
db.close()
