# %%
import sys

try:
    del sys.modules['contrib.action_space']
except:
    pass

from contrib.action_space import ActionSpace, IBMQHardwareArchitecture

# %%
space = ActionSpace(IBMQHardwareArchitecture('tokyo'))

# %%
space.num_qubits
# Out:
# 20

# %%
space.num_bridge
# Out:
# 148

# %%
space.num_swap
# Out:
# 86

# %%
space.num_route_actions
# Out:
# 234

# %%
space.num_trans
# Out:
# 7

# %%
space.num_trans_actions
# Out:
# 14

# %%
space.size
# Out:
# 250

# %%
space.to_gym_space()
# Out:
# Discrete(250)

# %%
space
# Out:
# ActionSpace(Size=250)

# %%
space.ACTION_FINISH
# Out:
# '<finish>'

# %%
space.ACTION_START
# Out:
# '<start>'
