# %%
import sys

try:
    del sys.modules['contrib.action_space']
except:
    pass

from contrib.action_space import ActionSpace, IBMQHardwareArchitecture

# %%
space = ActionSpace(IBMQHardwareArchitecture('tokyo'))

# %%
space.num_qubits
# Out:
# 20

# %%
space.num_bridge
# Out:
# 148

# %%
space.num_swap
# Out:
# 86

# %%
space.num_route_actions
# Out:
# 234

# %%
space.num_trans
# Out:
# 7

# %%
space.num_trans_actions
# Out:
# 14

# %%
space.size
# Out:
# 249

# %%
space.to_gym_space()
# Out:
# Discrete(249)

# %%
space
# Out:
# ActionSpace(Size=249)

# %%
space.ACTION_FINISH
# Out:
# '<finish>'

# %%
space.action_list
# Out:
# [(<qiskit.transpiler.passes.optimization.commutative_cancellation.CommutativeCancellation at 0x16334bd10>,
#   0),
#  (<qiskit.transpiler.passes.optimization.commutative_inverse_cancellation.CommutativeInverseCancellation at 0x1639a8cb0>,
#   0),
#  (<qiskit.transpiler.passes.optimization.inverse_cancellation.InverseCancellation at 0x163a29a90>,
#   0),
#  (<qiskit.transpiler.passes.optimization.optimize_1q_gates.Optimize1qGates at 0x163a2a390>,
#   0),
#  (<qiskit.transpiler.passes.optimization.optimize_1q_commutation.Optimize1qGatesSimpleCommutation at 0x163a29c70>,
#   0),
#  (<qiskit.transpiler.passes.optimization.optimize_swap_before_measure.OptimizeSwapBeforeMeasure at 0x163a29df0>,
#   0),
#  (<qiskit.transpiler.passes.optimization.remove_identity_equiv.RemoveIdentityEquivalent at 0x163a2b890>,
#   0),
#  (0, 1),
#  (0, 5),
#  (1, 0),
#  (1, 2),
#  (1, 6),
#  (1, 7),
#  (2, 1),
#  (2, 3),
#  (2, 6),
#  (2, 7),
#  (3, 2),
#  (3, 4),
#  (3, 8),
#  (3, 9),
#  (4, 3),
#  (4, 8),
#  (4, 9),
#  (5, 0),
#  (5, 6),
#  (5, 10),
#  (5, 11),
#  (6, 1),
#  (6, 2),
#  (6, 5),
#  (6, 7),
#  (6, 10),
#  (6, 11),
#  (7, 1),
#  (7, 2),
#  (7, 6),
#  (7, 8),
#  (7, 12),
#  (7, 13),
#  (8, 3),
#  (8, 4),
#  (8, 7),
#  (8, 9),
#  (8, 12),
#  (8, 13),
#  (9, 3),
#  (9, 4),
#  (9, 8),
#  (9, 14),
#  (10, 5),
#  (10, 6),
#  (10, 11),
#  (10, 15),
#  (11, 5),
#  (11, 6),
#  (11, 10),
#  (11, 12),
#  (11, 16),
#  (11, 17),
#  (12, 7),
#  (12, 8),
#  (12, 11),
#  (12, 13),
#  (12, 16),
#  (12, 17),
#  (13, 7),
#  (13, 8),
#  (13, 12),
#  (13, 14),
#  (13, 18),
#  (13, 19),
#  (14, 9),
#  (14, 13),
#  (14, 18),
#  (14, 19),
#  (15, 10),
#  (15, 16),
#  (16, 11),
#  (16, 12),
#  (16, 15),
#  (16, 17),
#  (17, 11),
#  (17, 12),
#  (17, 16),
#  (17, 18),
#  (18, 13),
#  (18, 14),
#  (18, 17),
#  (18, 19),
#  (19, 13),
#  (19, 14),
#  (19, 18),
#  (0, 2),
#  (0, 6),
#  (0, 7),
#  (0, 10),
#  (0, 11),
#  (1, 3),
#  (1, 5),
#  (1, 8),
#  (1, 10),
#  (1, 11),
#  (1, 12),
#  (1, 13),
#  (2, 0),
#  (2, 4),
#  (2, 5),
#  (2, 8),
#  (2, 9),
#  (2, 10),
#  (2, 11),
#  (2, 12),
#  (2, 13),
#  (3, 1),
#  (3, 6),
#  (3, 7),
#  (3, 12),
#  (3, 13),
#  (3, 14),
#  (4, 2),
#  (4, 7),
#  (4, 12),
#  (4, 13),
#  (4, 14),
#  (5, 1),
#  (5, 2),
#  (5, 7),
#  (5, 12),
#  (5, 15),
#  (5, 16),
#  (5, 17),
#  (6, 0),
#  (6, 3),
#  (6, 8),
#  (6, 12),
#  (6, 13),
#  (6, 15),
#  (6, 16),
#  (6, 17),
#  (7, 0),
#  (7, 3),
#  (7, 4),
#  (7, 5),
#  (7, 9),
#  (7, 10),
#  (7, 11),
#  (7, 14),
#  (7, 16),
#  (7, 17),
#  (7, 18),
#  (7, 19),
#  (8, 1),
#  (8, 2),
#  (8, 6),
#  (8, 11),
#  (8, 14),
#  (8, 16),
#  (8, 17),
#  (8, 18),
#  (8, 19),
#  (9, 2),
#  (9, 7),
#  (9, 12),
#  (9, 13),
#  (9, 18),
#  (9, 19),
#  (10, 0),
#  (10, 1),
#  (10, 2),
#  (10, 7),
#  (10, 12),
#  (10, 16),
#  (10, 17),
#  (11, 0),
#  (11, 1),
#  (11, 2),
#  (11, 7),
#  (11, 8),
#  (11, 13),
#  (11, 15),
#  (11, 18),
#  (12, 1),
#  (12, 2),
#  (12, 3),
#  (12, 4),
#  (12, 5),
#  (12, 6),
#  (12, 9),
#  (12, 10),
#  (12, 14),
#  (12, 15),
#  (12, 18),
#  (12, 19),
#  (13, 1),
#  (13, 2),
#  (13, 3),
#  (13, 4),
#  (13, 6),
#  (13, 9),
#  (13, 11),
#  (13, 16),
#  (13, 17),
#  (14, 3),
#  (14, 4),
#  (14, 7),
#  (14, 8),
#  (14, 12),
#  (14, 17),
#  (15, 5),
#  (15, 6),
#  (15, 11),
#  (15, 12),
#  (15, 17),
#  (16, 5),
#  (16, 6),
#  (16, 7),
#  (16, 8),
#  (16, 10),
#  (16, 13),
#  (16, 18),
#  (17, 5),
#  (17, 6),
#  (17, 7),
#  (17, 8),
#  (17, 10),
#  (17, 13),
#  (17, 14),
#  (17, 15),
#  (17, 19),
#  (18, 7),
#  (18, 8),
#  (18, 9),
#  (18, 11),
#  (18, 12),
#  (18, 16),
#  (19, 7),
#  (19, 8),
#  (19, 9),
#  (19, 12),
#  (19, 17),
#  (<qiskit.transpiler.passes.optimization.commutative_cancellation.CommutativeCancellation at 0x16334bd10>,
#   1),
#  (<qiskit.transpiler.passes.optimization.commutative_inverse_cancellation.CommutativeInverseCancellation at 0x1639a8cb0>,
#   1),
#  (<qiskit.transpiler.passes.optimization.inverse_cancellation.InverseCancellation at 0x163a29a90>,
#   1),
#  (<qiskit.transpiler.passes.optimization.optimize_1q_gates.Optimize1qGates at 0x163a2a390>,
#   1),
#  (<qiskit.transpiler.passes.optimization.optimize_1q_commutation.Optimize1qGatesSimpleCommutation at 0x163a29c70>,
#   1),
#  (<qiskit.transpiler.passes.optimization.optimize_swap_before_measure.OptimizeSwapBeforeMeasure at 0x163a29df0>,
#   1),
#  (<qiskit.transpiler.passes.optimization.remove_identity_equiv.RemoveIdentityEquivalent at 0x163a2b890>,
#   1),
#  '<finish>']
