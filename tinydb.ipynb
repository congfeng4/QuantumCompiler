# %%
import shelve

# %%
db = shelve.open('./output/db/nam_circs')

# %%
list(db.keys())
# Out:
# ['tof_3.qasm-star',
#  'tof_3.qasm-ring',
#  'barenco_tof_3.qasm-star',
#  'barenco_tof_3.qasm-ring',
#  'tof_4.qasm-star',
#  'tof_4.qasm-ring',
#  'tof_5.qasm-star',
#  'barenco_tof_4.qasm-star',
#  'vbe_adder_3.qasm-star',
#  'csla_mux_3.qasm-star',
#  'barenco_tof_5.qasm-star',
#  'gf2^4_mult.qasm-star',
#  'tof_10.qasm-star',
#  'gf2^5_mult.qasm-star',
#  'ham15-low.qasm-star']
