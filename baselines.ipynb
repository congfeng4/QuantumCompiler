# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit.transpiler import CouplingMap, Target
from qiskit.transpiler import PassManager

# 示例：生成 level=3 的 PassManager
pm = generate_preset_pass_manager(
    optimization_level=3,
    # target=Target.from_configuration({'gates': ['cx', 'rz', 'sx', 'x']}),
    coupling_map=CouplingMap.from_line(5)
)

# %%
pm.optimization.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2835x1620>

# %%
pm = generate_preset_pass_manager(
    optimization_level=2,
    # target=Target.from_configuration({'gates': ['cx', 'rz', 'sx', 'x']}),
    coupling_map=CouplingMap.from_line(5)
)
pm.optimization.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2176x1716>

# %%
type(pm.optimization)
# Out:
# qiskit.transpiler.passmanager.PassManager

# %%
dir(pm.optimization)
# Out:
# ['__abstractmethods__',
#  '__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_flatten_tasks',
#  '_passmanager_backend',
#  '_passmanager_frontend',
#  '_tasks',
#  'append',
#  'draw',
#  'max_iteration',
#  'property_set',
#  'remove',
#  'replace',
#  'run',
#  'to_flow_controller']

# %%
pm = generate_preset_pass_manager(
    optimization_level=1,
    # target=Target.from_configuration({'gates': ['cx', 'rz', 'sx', 'x']}),
    coupling_map=CouplingMap.from_line(5)
)
pm.optimization.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1043x1313>
